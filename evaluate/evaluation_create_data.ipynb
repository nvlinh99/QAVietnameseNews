# %% [markdown]
# # Read JSON file

# %%
import json

# Open and read the JSON file
# with open('data_crawl/combined-newsqa-data-v1-format.json', 'r') as file:
#     data = json.load(file)
with open('./data/combined-newsqa-data-v1.json', 'r') as file:
    data = json.load(file)

# Function to extract text, questions (q), and answers, filtering out {'noAnswer': True} and duplicates
def extract_data(data, limit=None):
    extracted_data = []
    
    # Loop through each story, limited by the specified count
    for index, story in enumerate(data.get("data", [])):
        if limit is not None and index >= limit:
            break

        text = story.get("text", "") ## Clean up new line
        questions = story.get("questions", [])
        
        # Create a list to hold questions and their corresponding answers
        questions_with_answers = []
        
        # Loop through each question and its associated answers
        for question in questions:
            q = question.get("q", "")
            answers = set()  # Use set to avoid duplicate answers
            
            # Extract and filter answers
            for answer in question.get("answers", []):
                sourcer_answers = answer.get("sourcerAnswers", [])
                
                # Filter out {'noAnswer': True} and convert positions to text
                for sourcer_answer in sourcer_answers:
                    if "noAnswer" not in sourcer_answer:
                        start = sourcer_answer.get("s", -1)
                        end = sourcer_answer.get("e", -1) - 1
                        
                        # Extract the word from the text
                        if start != -1 and end != -1:
                            extracted_text = text[start:end].strip()
                            answers.add(extracted_text)
            
            # Convert the set to a list of dictionaries
            unique_answers = list(answers)
            
            if unique_answers:  # Check if the answers list is not empty
                questions_with_answers.append({
                    "question": q,
                    "answers": unique_answers
                })
        
        # Append the story data with text and its questions with answers
        extracted_data.append({
            "text": text,
            "qa": questions_with_answers
        })
    
    return extracted_data

# Extracted data
extracted_data = extract_data(data, limit = 200) # Only took 100/12400 stories because takes all the stories makes the txt files too big

# %%
# Print extracted data
for item in extracted_data:
    print(f"Text: {item['text'][:50]}")
    print("----------------")
    for qa in item['qa']:
        print(f"Question: {qa['question']}")
        for answer in qa['answers']:
            # print(f"Start: {answer['start']}, End: {answer['end']}")
            # print(f"Answer: '{answer['extracted_text']}'")
            print(f"Answer: '{answer}'")
    print("#######################")
# Out:
# Text: NEW DELHI, India (CNN) -- A high court in northern
# ----------------
# Question: What was the amount of children murdered?
# Answer: '19'
# Question: When was Pandher sentenced to death?
# Answer: 'in February.'
# Answer: 'February.'
# Question: The court aquitted Moninder Singh Pandher of what crime?
# Answer: 'A high'
# Answer: 'rape and murder'
# Question: who was acquitted
# Answer: 'Moninder Singh Pandher'
# Question: who was sentenced
# Answer: 'Moninder Singh Pandher'
# Answer: 'to death by a lower court in February.'
# Question: What was Moninder Singh Pandher acquitted for?
# Answer: 'the killing of a teen in a case dubbed "the house of horrors."'
# Answer: 'the killing of a teen'
# Answer: 'killing of a teen'
# Question: Who was sentenced to death in February?
# Answer: 'Moninder Singh Pandher'
# Question: how many people died
# Answer: '19'
# Question: How many children and young women were murdered?
# Answer: '19'
# #######################
# Text: (CNN) -- Fighting in the volatile Sudanese region
# ----------------
# Question: Where was one employee killed?
# Answer: 'Sudanese region of Darfur'
# Answer: 'Seleia,'
# Question: what happened in chad
# Answer: 'attempt by rebels there to topple the government.'
# Answer: 'Refugee camps'
# Answer: 'influx of refugees'
# Question: Who is fighting in Chad?
# Answer: 'government and rebels'
# Answer: 'government forces, rebel groups and allied militia groups'
# Answer: 'rebel-government'
# Question: What is Darfur wracked by?
# Answer: 'rebels'
# Answer: 'Fighting'
# Answer: 'fled violence'
# Answer: 'militia attacks'
# Question: How many have recently crossed to Chad?
# Answer: '12,000'
# Question: How many people have crossed to Chad in last few days?
# Answer: '12,000'
# Question: Who was killed in Dafur?
# Answer: 'employees'
# Answer: 'Red Cross employee dead,'
# Answer: 'International Committee of the Red Cross'
# Answer: 'Red Cross'
# Answer: 'one of its employees'
# Question: what caused the war
# Answer: 'proxy'
# Answer: 'over Darfur.'
# #######################
# Text: Johannesburg (CNN) -- Miffed by a visa delay that
# ----------------
# Question: who did say South Africa did not issue a visa on time?
# Answer: 'Desmond Tutu'
# Answer: 'his spokesman'
# Answer: 'Archbishop Desmond Tutu'
# Question: who is responsible for all this
# Answer: 'government.'
# Answer: 'nation failed to issue him a visa in time,'
# Answer: 'his government'
# Question: what is the African National Congress ?
# Answer: 'fight against the system of apartheid, or legal racial separation, that was present in South Africa until 1994.'
# Answer: 'which is rooted in the fight against the system of apartheid, or legal racial separation, that was present in South Africa until 1994.'
# Answer: 'rooted'
# Answer: 'which'
# Question: Who does the African National Congress say should calm down?
# Answer: 'Tutu'
# Question: Who says the government is acting worse than apartheid regime?
# Answer: 'Archbishop Desmond Tutu'
# Question: Who was denied visa to South Africa in 2009?
# Answer: 'Dalai Lama'
# #######################
# Text: (CNN)  -- England international footballer Steven
# ----------------
# Question: How many years old was the businessman?
# Answer: '29-year-old'
# Question: What did Gerrard admit
# Answer: 'throwing three punches'
# Question: Who was cleared by a Liverpool court?
# Answer: 'Steven Gerrard'
# Question: Who was cleared of charges
# Answer: 'Steven Gerrard'
# Question: What did Gerrard admit doing?
# Answer: 'admitted throwing three punches'
# Answer: 'punching businessman Marcus McGhee.'
# Answer: 'admitted throwing three punches but said only one connected.'
# Question: What did the Jury accept
# Answer: 'They accepted the Liverpool captain's version that he acted in self defense'
# Answer: '"Can I just say how pleased I am with today's verdict,"'
# Question: Who did Gerrard admit to punching?
# Answer: 'Marcus McGhee.'
# Answer: 'found not guilty'
# Answer: 'businessman Marcus McGhee.'
# Question: Who was cleared of affray charge?
# Answer: 'Steven Gerrard'
# #######################
# Text: BAGHDAD, Iraq (CNN)  -- At least 6,000 Christians
# ----------------
# Question: What frightened the families?
# Answer: 'series of killings and threats by Muslim extremists'
# Answer: 'Iraqi officials'
# Answer: 'a series of killings and threats by Muslim extremists ordering them to convert to Islam or face death.'
# Question: How many Christian families have been displaced
# Answer: 'than were reported to be'
# Answer: 'at least 70 more'
# Answer: '1,424'
# Answer: 'fled the northern Iraqi city of Mosul'
# Answer: 'At least 6,000'
# Question: What did extremists order thdm to do
# Answer: 'Islam or face death.'
# Answer: 'convert'
# Question: How many families have been displaced?
# Answer: '1,424'
# Question: What were the families ordered to do?
# Answer: 'Islam or face death.'
# Answer: 'convert'
# Question: How many Christians have been slain
# Answer: 'Fourteen'
# Question: Who was displaced?
# Answer: 'At least 6,000 Christians'
# Answer: '1,424 families,'
# Question: Who are the extremists ordering to convert to Islam?
# Answer: 'Christians'
# Answer: '6,000 Christians'
# Answer: 'Muslim'
# Question: How many Fourteen Christians have been slain in Mosul?
# Answer: '6,000'
# Answer: 'fled'
# Answer: '1,424 families,'
# #######################
# Text: (CNN) -- Pope John Paul II used to beat himself wi
# ----------------
# Question: what Pope used to beat himself?
# Answer: 'John Paul II'
# Question: who "a particular pant-belt" to beat himself, book says?
# Answer: 'John Paul II'
# Answer: 'Pope'
# Question: who says "Why he is a Saint: The True story of John Paul II"?
# Answer: 'Slawomir Oder,'
# Question: what Journalist compares flagellation to fasting or other?
# Answer: 'David Gibson,'
# Answer: 'Slawomir Oder,'
# Question: what did he do
# Answer: 'floor to bring himself'
# Answer: 'used to beat himself with a belt and sleep on a bare floor'
# Answer: 'closer to Christ,'
# Answer: 'beat himself with a belt and sleep on'
# Question: there John Paul II slept?
# Answer: 'bare floor'
# Question: what pope is this
# Answer: 'John Paul II'
# Question: when John Paul wrot a apostolic letter on suffering?
# Answer: '1984.'
# #######################
# Text: CNN affiliates report on where job seekers are fin
# ----------------
# Question: Who is hiring?
# Answer: 'the states'
# Answer: 'census'
# Answer: 'The naval facility in China Lake,'
# Answer: '2010'
# Answer: 'the federal government'
# Question: What does the navy need?
# Answer: 'workers'
# Question: Who needs rocket scientists at one of it's centers?
# Answer: 'naval facility in China Lake, California,'
# Question: What kind of scientists does the Navy need?
# Answer: 'engineering, physics, chemistry and other sciences.'
# Question: What kind of club in Rhode Island needs more workers?
# Answer: 'strip'
# Question: What does the strip club in Rhode Island need more of?
# Answer: 'hire 25 to 30'
# Answer: 'workers'
# Answer: 'people.'
# Question: Census bureaus are hiring people from where?
# Answer: 'Denver area.'
# Question: what government organization is hiring?
# Answer: 'census bureau,'
# Answer: 'federal'
# Question: Who needs more dancers?
# Answer: 'Rhode Island, that owners'
# Answer: 'hire 25 to 30'
# Answer: 'people.'
# #######################
# Text: WASHINGTON (CNN) -- One of the Marines shown in a
# ----------------
# Question: What war was the Iwo Jima battle a part of?
# Answer: 'II'
# Answer: 'World'
# Question: Where was Michael Strank born?
# Answer: 'WASHINGTON'
# Answer: 'Czechoslovakia'
# Question: Where was STrank killed?
# Answer: 'on the island'
# Question: Who was among six who famously raised flag on Iwo Jima?
# Answer: 'Sgt. Michael Strank,'
# Question: What rank did Michael Strank hold?
# Answer: 'Sgt.'
# Question: When was the certificate given to his sister?
# Answer: 'of U.S. citizenship'
# Answer: 'Tuesday.'
# Question: Who was killed on Iwo Jima in World War II ?
# Answer: 'Strank'
# Answer: 'Michael Strank,'
# Question: WHERE WAS Strank, born?
# Answer: 'Czechoslovakia'
# Question: What did Strank not receive?
# Answer: 'citizenship papers.'
# Question: Where was Strank born?
# Answer: 'Czechoslovakia'
# Question: Who received the certificate?
# Answer: 'Sgt. Michael Strank,'
# Answer: 'Strank's younger sister, Mary Pero.'
# Question: Who was among the six who raised the flag in Iwo Jima?
# Answer: 'Sgt. Michael Strank,'
# Answer: 'Strank'
# #######################
# Text: TEHRAN, Iran (CNN) -- Iran's parliament speaker ha
# ----------------
# Question: Iran criticizes who?
# Answer: 'President-elect Barack Obama'
# Answer: 'U.S. President-elect Barack Obama'
# Question: What are US and Iran relations tensioned about?
# Answer: 'development of a nuclear weapon is unacceptable.'
# Answer: 'nuclear program.'
# Question: Who said Obama should apply campaign message?
# Answer: 'Ali Larijani'
# Question: What should Obama apply according to speaker?
# Answer: 'Ali Larijani'
# Answer: 'U.S. dealings with Iran.'
# Answer: 'his campaign message of change'
# Question: US - Iran tensions are high over what?
# Answer: 'nuclear weapon'
# Answer: 'nuclear program.'
# Answer: 'development'
# Question: Who was the President of the US at this time?
# Answer: 'Barack Obama'
# Answer: 'Larijani'
# Answer: 'Mahmoud Ahmadinejad'
# Question: Who has tensions over Tehran's nuclear ambitions?
# Answer: 'the United States'
# Answer: 'program, which will be taking a step in the wrong direction."'
# Answer: '"What is expected is a change in strategy, not the repetition of objections to Iran's'
# Answer: 'U.S.'
# Question: Who criticized Obama ?
# Answer: 'Iran's parliament speaker'
# Question: Parliamentary speaker says who should apply campaign message of change?
# Answer: 'Obama'
# Answer: 'his'
# Answer: 'Ali Larijani said Saturday that Obama'
# Answer: 'U.S. President-elect Barack Obama'
# Answer: 'to U.S. dealings with Iran.'
# Answer: 'of'
# Question: What kind of weapons are being discussed?
# Answer: 'nuclear'
# Question: Who criticized Obama for saying nuclear weapon development is unaccaptable?
# Answer: 'Ali Larijani'
# Answer: 'parliament speaker'
# Answer: 'Iran's parliament speaker'
# Question: What basic reason is there for US-Iranian tensions to be high?
# Answer: 'nuclear technology,'
# Answer: 'nuclear program,'
# #######################
# Text: (CNN) -- Jewish organizations called for a Romania
# ----------------
# Question: Who is Radu Mazare?
# Answer: 'mayor of the town of Constanta,'
# Answer: 'mayor'
# Answer: 'mayor of'
# Answer: 'Constanta,'
# Question: Who is calling for the official's resignation?
# Answer: 'organizations'
# Answer: 'Jewish'
# Question: What did Mazarin do?
# Answer: 'Nazi uniform during'
# Answer: 'fashion show over the weekend.'
# Answer: 'wore'
# Answer: 'Nazi uniform'
# Answer: 'he wore a Nazi uniform during a fashion show'
# Question: What did the mayor wear?
# Answer: 'a Nazi uniform'
# Answer: 'Nazi uniform'
# Question: What organizations  are calling for his resignation?
# Answer: 'Jewish'
# Question: What did Radu Mazare say he did not notice?
# Answer: 'wore'
# Answer: 'the Nazi swastika symbol on the uniform before'
# Answer: 'the uniform'
# Answer: 'Nazi swastika symbol'
# Question: What did the mayor do?
# Answer: 'wore a Nazi uniform'
# Question: What did the Jews call for?
# Answer: 'a Romanian official to resign and face a criminal investigation'
# Question: Who wore a Nazi uniform?
# Answer: 'Radu Mazare,'
# #######################
# Text: (CNN) -- A phone hacking scandal may have cost Rup
# ----------------
# Question: How many followers does Rupert have?
# Answer: '45,000'
# Question: How many followers does Murdoch have on twitter?
# Answer: '45,000'
# Question: What do his tweets talk about?
# Answer: 'politics,'
# Answer: 'family, work and politics,'
# Answer: 'family, work'
# Question: What is his age?
# Answer: '80-year-old'
# Question: what age is the person?
# Answer: '80-year-old'
# Question: What types of tweets does Murdoch write?
# Answer: 'about family, work and politics,'
# Answer: 'family, work and politics,'
# Question: Which news channel was this information confirmed to?
# Answer: 'CNN'
# Question: What is number of followers Murdoch has?
# Answer: '45,000'
# Answer: 'more than 45,000'
# #######################
# Text: ATLANTA, Georgia (CNN) -- Jeremy Piven is the kind
# ----------------
# Question: What is the HBO series called?
# Answer: '"Entourage"'
# Answer: '"Entourage."'
# Question: Who has ideas for an "Entourage" movie?
# Answer: 'Piven:'
# Question: What network is "Entourage" on?
# Answer: 'HBO's'
# Question: Who plays a used car salesman?
# Answer: 'Jeremy Piven'
# Answer: 'a'
# Answer: '"The Goods: Live Hard, Sell Hard,"'
# Answer: 'Piven'
# Answer: 'in "The Goods."'
# Answer: 'he'
# Answer: 'Jeremy Piven stars as a'
# Question: Who does Jeremy Piven play?
# Answer: 'Will Ferrell is so brilliant."'
# Answer: 'a used car salesman'
# Question: What is the name of the movie?
# Answer: '"The Goods: Live Hard, Sell Hard,"'
# Answer: '"Entourage."'
# Answer: '"The Goods."'
# Question: What HBO series will continue as long as it stays fresh?
# Answer: '"Entourage"'
# #######################
# Text: Berlin, Germany (CNN)  -- A bomb scare that affect
# ----------------
# Question: How many flights were affects?
# Answer: '100'
# Question: What did police say about why the man fled?
# Answer: 'may simply have been in a hurry, grabbed his things and left the airport.'
# Answer: 'computer bag tested positive for explosives,'
# Answer: 'his laptop computer bag tested positive for explosives,'
# Answer: 'the'
# Question: is the search being called a manhunt?
# Answer: 'huge'
# Question: What terminal did passengers have to take?
# Answer: '2,'
# Question: Who is seeking the man?
# Answer: 'Police'
# Question: what tested positive for explosives?
# Answer: 'laptop computer bag'
# Question: Have the police found the man yet?
# Answer: 'still trying to find the'
# Answer: 'They are still trying to find the'
# Answer: 'trying to find the'
# Question: what terminal did the Passengers have to leave ?
# Answer: '2,'
# Question: What did the man do at the airport?
# Answer: 'grabbed his things and left the'
# Answer: 'flee from security officers'
# Answer: 'appeared to flee from security officers'
# #######################
# Text: SAVANNAH, Georgia (CNN)  -- What does it really ta
# ----------------
# Question: What does Designer Isabel Toledo say?
# Answer: '"Bravery,"'
# Answer: '"Go out there and look at things, look at things well. Study them; the smallest things can inspire you. That will make you able to do'
# Answer: 'think you have to have all this backing coming into a big industry. I didn't do that, I started from the bottom and as a matter of fact you can only go up," said'
# Answer: 'you want on any level. Many times kids'
# Answer: 'of the first lady's attention-grabbing lemongrass yellow wool and lace ensemble that she wore for the inauguration of her husband President Obama.'
# Question: What do analysts say about the Fashion industry job market say?
# Answer: 'as a whole is feeling a greater level of lost revenues and in turn has lost opportunities for sustaining volume and even more so for growth,"'
# Answer: 'the new'
# Answer: '"Fashion is being hit particularly hard'
# Answer: '"Fashion is being hit particularly hard in the new'
# Question: What industry is being hit hard?
# Answer: '"Fashion'
# Question: Which job market is being hit very hard?
# Answer: '"Fashion'
# Question: What is the name of the college?
# Answer: 'of Art and Design.'
# Answer: 'Savannah'
# Question: What did the designer make for years?
# Answer: 'President Obama.'
# Answer: 'doll clothes'
# Question: Who do Students at Savannah College of Art and Design get advice from?
# Answer: 'Yigal Azrouël'
# Answer: 'Nilsson.'
# Question: Which students get advice?
# Answer: 'new graduates'
# Answer: 'at the Savannah College of Art and Design.'
# Answer: 'critiquing 23'
# Question: Who made doll clothing for years?
# Answer: '"Jason Wu,'
# Answer: 'Michelle Obama?'
# #######################
# Text: (CNN) -- Les Paul never stopped tinkering, said He
# ----------------
# Question: when does paul died?
# Answer: 'Thursday'
# Question: what wasn't particularly popular when introduced?
# Answer: 'a solid-body guitar'
# Answer: 'the Gibson Les Paul'
# Question: Who made recommendations on how to improve guitars?
# Answer: 'Les Paul'
# Question: What wasn't popular when introduced?
# Answer: 'the Gibson Les Paul'
# Answer: 'Gibson Les Paul'
# Question: Who died on thursday at 94
# Answer: 'Les Paul'
# Question: What was Paul's age at death?
# Answer: '94.'
# Question: What did the gibson ceo say?
# Answer: 'recommendations on how to improve guitars,'
# Answer: 'eponymous'
# Answer: 'thousands.'
# Answer: 'Les Paul was constantly making'
# Answer: 'with'
# Question: what was the recommendations of les paul?
# Answer: 'how to improve guitars,'
# Answer: 'on how to improve guitars,'
# #######################
# Text: United Nations (CNN) -- Confronted with the prospe
# ----------------
# Question: What did the French president say?
# Answer: 'urged the body to recognize Palestine as a non-member state,'
# Answer: 'recognize Palestine as a non-member state,'
# Answer: 'urged the body to recognize Palestine as a non-member state, calling for a more definitive timetable for Israeli-Palestinian peace talks. But he also warned that a U.S. veto of the bid for full membership in the Security Council could be dangerous and might spark violence.'
# Question: What did Obama do?
# Answer: 'issued a sharp rebuke'
# Question: Who did Obama meet with?
# Answer: 'Israeli Prime Minister Benjamin Netanyahu'
# Question: What did Frances President say?
# Answer: 'French'
# Answer: 'urged the body to recognize Palestine as a non-member state,'
# Answer: 'urged the body to recognize Palestine as a non-member state, calling for a more definitive timetable for Israeli-Palestinian peace talks. But he also warned that a U.S. veto of the bid for full membership in the Security Council could be dangerous and might spark violence.'
# Answer: 'Nicolas Sarkozy urged the body to recognize Palestine as a non-member state, calling for a more definitive timetable for Israeli-Palestinian peace talks.'
# Question: What could spark violence?
# Answer: 'full U.N. membership,'
# Answer: 'U.S. veto'
# Answer: 'Palestinian bid'
# Answer: 'a U.S. veto of the bid for full membership in the Security Council'
# Question: What did Argentina's president say?
# Answer: '"non-inclusion of Palestine (at the United Nations) this year will create greater insecurity."'
# Question: What will the UN do?
# Answer: 'block a Palestinian membership application'
# #######################
# Text: BOSTON, Massachusetts (CNN) -- A 23-year-old medic
# ----------------
# Question: What was he guilty of?
# Answer: 'first-degree murder charge'
# Answer: 'first-degree murder'
# Question: Who pleads not guilty to slaying woman?
# Answer: 'Philip Markoff'
# Question: What was Philip Markoff charged with?
# Answer: 'killing a woman and robbing another'
# Answer: 'first-degree murder'
# Question: Who was killed?
# Answer: 'Julissa Brisman,'
# Question: What were the charges?
# Answer: '"the armed and forcible confinement"'
# Answer: 'unlawful firearm possession,'
# Answer: 'first-degree murder'
# Question: when did this happen
# Answer: 'Monday'
# Question: was he convicted
# Answer: 'indicted him on seven counts, including first-degree murder.'
# Question: What were both April incidents linked to?
# Answer: 'ads on the popular Web site Craigslist.'
# #######################
# Text: (CNN Student News)  -- Discussion Questions
#
#
#
#
#
# 1
# ----------------
# Question: What are the activities for?
# Answer: 'to encourage your students to learn about and appreciate the history, culture and achievements of African-Americans.'
# Answer: 'encourage your students to learn about and appreciate the history, culture and achievements of African-Americans.'
# Question: What does this month help students do?
# Answer: 'learn about and appreciate the history, culture and achievements of African-Americans.'
# Question: What month is Black History Month?
# Answer: 'February'
# Question: Who do the questions accommodate?
# Answer: 'African-Americans'
# Answer: 'history, culture and achievements of African-Americans.'
# Question: What does February celebrate?
# Answer: 'black history'
# Answer: 'recognize the accomplishments of African-Americans,'
# Answer: 'accomplishments of African-Americans,'
# Question: Which month is Black History Month?
# Answer: 'February'
# Question: When is Black History Month?
# Answer: 'February 2010:'
# Answer: 'February'
# Question: What do the students learn?
# Answer: 'the history, culture and achievements of African-Americans.'
# #######################
# Text: UNITED NATIONS (CNN)  -- Libyan leader Moammar Gad
# ----------------
# Question: What requires unified action?
# Answer: 'confronting various world crises, such as climate change and food shortages,'
# Answer: 'confronting various world crises, such as climate change and food shortages, but he aimed his ire at the world body and the United States.'
# Answer: 'in confronting various world crises, such as climate change and food shortages,'
# Question: What was the conclusion on the issues?
# Answer: 'world unity in confronting various world crises,'
# Question: what does Gadhafi say UN security council brings?
# Answer: 'crises, such as climate change and food shortages,'
# Answer: 'unfairness of the structure of the U.N.'
# Question: What does Gadhafi say?
# Answer: 'broached conspiracy theories, urged probes into U.S. military activities, and took aim at the structure and the actions of the Security Council,'
# Answer: 'slamming both the U.N. Security Council and the United States.'
# Answer: 'delivered a lengthy, rambling address'
# Answer: 'called for world unity in confronting various world crises, such as climate change and food shortages,'
# Question: What is unfair?
# Answer: 'the structure of the U.N. Security Council,'
# Question: what did Libyan leader tell UN general assembly?
# Answer: 'He broached conspiracy theories, urged probes into U.S. military activities, and took aim at the structure and the actions of the Security Council,'
# Question: What were the five nations?
# Answer: 'United States, Russia, China, France and Britain,'
# Answer: 'United States, Russia, China, France'
# Answer: 'Britain,'
# #######################
# Text: (CNN) -- Barcelona midfielder Alexander Hleb has t
# ----------------
# Question: What has Hleb chosen to do?
# Answer: 'Stuttgart'
# Answer: 'returning'
# Answer: 'swap deal that saw Zlatan Ibrahimovic and Samuel Eto'o switch clubs'
# Answer: 'be part of the swap deal'
# Question: Who did he choose instead?
# Answer: 'Stuttgart'
# Answer: 'returning'
# Answer: 'to Bundesliga club Stuttgart'
# Question: How long is the loan deal?
# Answer: 'for the season.'
# Answer: 'the season.'
# Question: Who is invoked in the swap transfer?
# Answer: 'Zlatan Ibrahimovic and Samuel Eto'o'
# Answer: 'Samuel Eto'o'
# Answer: 'Zlatan Ibrahimovic'
# Question: Who turned down a switch to Inter Milan?
# Answer: 'a move'
# Answer: 'Bundesliga club Stuttgart on loan for the season.'
# Answer: 'midfielder Alexander Hleb has'
# Answer: 'midfielder Alexander Hleb'
# Answer: 'Barcelona'
# Answer: 'in favor of returning'
# Question: Who was expected to be part of the Ibrahimovic transfer?
# Answer: 'Alexander Hleb'
# Question: What had been expected?
# Answer: 'part of the swap deal that saw Zlatan Ibrahimovic and Samuel Eto'o switch clubs earlier this week.'
# Answer: 'be part of the swap deal that saw Zlatan Ibrahimovic and Samuel Eto'o switch clubs earlier this week.'
# Question: What position does Alexander Hleb play?
# Answer: 'midfielder'
# #######################
# Text: BAGHDAD, Iraq (CNN) -- Iraqi Security Forces captu
# ----------------
# Question: What are suspects blamed for?
# Answer: 'bombings, torturing of civilians, conducting attacks'
# Answer: 'warning insurgents'
# Answer: 'bombings, torturing of civilians, conducting attacks and warning insurgents about upcoming Iraqi and U.S. military operations,'
# Question: What is one of the suspects believed to have done?
# Answer: 'conducted more than 12 attacks since July.'
# Answer: 'in Iraq terror cells,'
# Answer: 'al Qaeda'
# Answer: 'be connected'
# Question: how many attacks have been done since July?
# Answer: '12'
# Question: is civilian torture related to terrorism?
# Answer: 'terror cells'
# Answer: 'torturing of'
# Answer: 'terror cells responsible for bombings, torturing of'
# Question: How many attacks is one of the suspects believed to have conducted?
# Answer: 'more than 12'
# Answer: '12'
# Answer: 'since July.'
# Answer: 'of the'
# Answer: 'is'
# Question: What is the suspect blamed for?
# Answer: 'warning insurgents'
# Answer: 'believed to be part of terror cells responsible'
# Answer: 'bombings, torturing'
# Answer: 'civilians, conducting attacks'
# Answer: 'bombings, torturing of civilians, conducting attacks and warning insurgents about upcoming Iraqi and U.S. military operations,'
# Answer: 'conducted more than 12 attacks since July.'
# Question: is the Islamic State of Iraq a terrorist group?
# Answer: 'and 21 suspected'
# Answer: 'known as The'
# Answer: 'from an umbrella'
# Answer: 'of al Qaeda in'
# Answer: 'of'
# Question: Who do the suspects include?
# Answer: '45 men from al Qaeda in Iraq and 21 suspected terrorists from an umbrella group of al Qaeda in Iraq known as The Islamic State of Iraq,'
# Answer: 'included 45 men from al Qaeda in Iraq and 21 suspected terrorists from an umbrella group of al Qaeda'
# #######################
# Text: (CNN) -- Two goals in five minutes at the start of
# ----------------
# Question: what did nigeria become
# Answer: 'fourth team to reach the semifinals'
# Question: WHo booked their place
# Answer: 'Egypt'
# Question: Who does Nigeria play?
# Answer: 'Egypt'
# Answer: 'will now face'
# Answer: 'Ghana'
# Question: Who are the defending champions?
# Answer: 'Egypt'
# Question: what did egypt do
# Answer: 'their place in the African Nations Cup semifinals with a battling 3-1 victory over Cameroon.'
# Answer: 'their place in the African Nations Cup semifinals'
# Answer: 'book'
# Question: how many goals did egypt score
# Answer: '3-1'
# Answer: 'Two'
# Question: What day was the game
# Answer: 'Thursday.'
# Question: What is the competition
# Answer: 'the African Nations Cup semifinals'
# Answer: 'African Nations Cup semifinals'
# Question: Egypt scored how many goals?
# Answer: 'Two'
# #######################
# Text: WASHINGTON (CNN) -- A soldier who reported for dut
# ----------------
# Question: What did she argue?
# Answer: 'would have no'
# Answer: 'was sent overseas.'
# Answer: 'because her husband travels for business and they would have no one to care for their children if'
# Answer: 'care for their children if'
# Answer: 'no one to care for their children'
# Question: Who else could have cared for the kids?
# Answer: 'no one'
# Question: what did the soldier report
# Answer: 'for duty'
# Answer: 'reported for duty'
# Question: When did she leave?
# Answer: 'June 2005.'
# Answer: 'four years ago.'
# Question: what did the lawyer say
# Answer: 'A soldier who reported for duty with her children in tow has'
# Answer: 'for a discharge,'
# Answer: 'her request'
# Answer: 'Army would grant her request and begin the process'
# Answer: 'told CNN the'
# Answer: 'for a discharge, her'
# Answer: 'been'
# Answer: 'Pagan's'
# Answer: 'A soldier who reported for duty with her children in tow has been granted her request'
# Answer: 'granted'
# Answer: 'of discharge again, this time for good.'
# Answer: 'CNN the Army would grant her request and begin the process of discharge again, this time for good.'
# Answer: 'said'
# Question: What did the soldier say?
# Answer: '"I'm a human being. I need to take care of my children. They don't have anybody else,"'
# Question: What happened to have the soldier recalled in the first place?
# Answer: 'September 11, 2001,'
# Answer: 'Individual Ready Reserve program.'
# Answer: 'as part of the Individual Ready Reserve program.'
# Question: Where does the woman live?
# Answer: 'Davidson, North Carolina,'
# #######################
# Text: (CNN)  -- When Kellogg's dumped its endorsement of
# ----------------
# Question: How many boxes were donated?
# Answer: '"Thousands of families benefited from the donation"'
# Answer: 'With food banks across the country reporting shortages of food, the donation was a welcome one,'
# Answer: '3,000'
# Question: What was on the cereal boxes they dumped?
# Answer: 'Michael Phelps'
# Question: Who received the boxes of cereal?
# Answer: 'San Francisco Food Bank'
# Question: What made them dump Michael Phelps?
# Answer: 'Olympic gold medalist using a bong,'
# Answer: 'after a photograph surfaced of the'
# Answer: 'a photograph surfaced of the'
# Question: Whose face was on the cereal boxes that were dumped?
# Answer: 'Michael Phelps'
# Question: Kellogg's donated how much cereal?
# Answer: 'two tons of'
# Answer: 'two tons'
# Question: What did Kellogg donate?
# Answer: 'two tons of cereal'
# Question: What did the director say?
# Answer: 'With food banks across the country reporting shortages of food, the donation was a welcome one,'
# Question: How many tons of cereal did Kelloggs donate?
# Answer: 'two'
# #######################
# Text: (CNN) -- Kyrgyzstan's president signed a bill Frid
# ----------------
# Question: Who is the President of Kyrgyzstan?
# Answer: 'Kurmanbek Bakiyev'
# Question: What is the Kyrgyzstan president doing?
# Answer: 'close an air base that the U.S. military uses'
# Answer: 'signed a bill'
# Answer: 'as a route for troops and supplies heading into Afghanistan,'
# Answer: 'signed a bill Friday to close an air base that the U.S. military uses'
# Question: Who is working to keep the operation open?
# Answer: 'the United States'
# Answer: 'United States'
# Question: What is the Manas baseusedfor?
# Answer: 'Air Base in Kyrgyzstan serves as a U.S. supply route for troops and supplies into Afghanistan.'
# Answer: 'Manas Air Base in Kyrgyzstan serves as a U.S. supply route for troops and supplies into Afghanistan.'
# Answer: 'serves as a U.S. supply route for troops and supplies into Afghanistan.'
# Question: Who may allow US Military supplies?
# Answer: 'Tajikistan and Uzbekistan,'
# Answer: 'Kyrgyzstan.'
# Question: What country is acting similarly to Tajikistan?
# Answer: 'Uzbekistan'
# Answer: 'Kyrgyzstan'
# Question: Who was used to transport key supplies?
# Answer: 'the U.S. military'
# Answer: 'Manas Air Base in Kyrgyzstan'
# Question: Where is the Manas base?
# Answer: 'Kyrgyzstan'
# Question: Who will allow U.S military supplies to head to Afghanistan?
# Answer: 'Uzbekistan'
# Answer: 'Tajikistan'
# Answer: 'Tajikistan and Uzbekistan'
# Question: What countries may allow U.S. supplies?
# Answer: 'Uzbekistan'
# Answer: 'Afghanistan,'
# Answer: 'Tajikistan'
# Answer: 'Tajikistan and Uzbekistan'
# Question: Which base is used for key supplies and troops?
# Answer: 'in Kyrgyzstan'
# Answer: 'Manas Air'
# #######################
# Text: Cleveland, Ohio (CNN) -- The niece of the mayor of
# ----------------
# Question: What did Frank Jackson say?
# Answer: '"I just want to know why, why he would do this,"'
# Answer: '"I love my niece very much and while she has made some decisions that have not been in her best interest, she has my full support,"'
# Answer: '"He took care of me, good care of me. I never would have thought there were some bodies in the house."'
# Question: What does Jackson say of his niece?
# Answer: 'very much and while she has made some decisions that have not been in her best interest, she has my full support,"'
# Answer: '"I love my'
# Question: With who has Lori Frazier been living between 2005 and 2007?
# Answer: 'Sowell,'
# Answer: 'Anthony'
# Question: What is Sowell charged with?
# Answer: 'registered sex offender'
# Answer: 'murder'
# Answer: 'murder after the remains of 11 victims were found at his home,'
# Question: What the FBI said?
# Answer: 'spokesman Scott Wilson has'
# Answer: 'Behavioral Science Unit are assisting Cleveland police, Cleveland'
# Answer: 'Agents from the'
# Question: Who Jackson loves?
# Answer: 'Lori Frazier,'
# Question: Who did Lori Frazier live with?
# Answer: 'Sowell,'
# Answer: 'Anthony'
# Question: what is Anthony Sowell charged with?
# Answer: 'murder'
# Question: When did Lori Frazier live with Anthony Sowell?
# Answer: 'from 2005 to 2007'
# Answer: '2005 to 2007'
# #######################
# Text: NEW YORK (CNN)  -- Authorities are seeking the pub
# ----------------
# Question: What name does the girl respond to?
# Answer: '"Amber"'
# Question: What was the girl's height?
# Answer: '5 feet, 6 inches tall,'
# Answer: '5 feet, 6 inches'
# Question: when was the girl found
# Answer: 'in Manhattan two weeks ago,'
# Answer: 'in midtown Manhattan around 12:30 a.m. October 9'
# Answer: 'two weeks ago,'
# Answer: '12:30 a.m. October 9'
# Answer: 'The'
# Question: On what day was the girl found?
# Answer: 'October 9'
# Answer: '12:30 a.m. October 9'
# Question: What age range do doctors believe the girl is?
# Answer: 'are estimating her'
# Answer: 'teenage'
# Answer: 'between 14 and 17.'
# Answer: 'to be between 14 and 17.'
# Answer: '14 and 17.'
# Question: what age is the girl
# Answer: 'between 14 and 17.'
# Question: Does the girl have a name?
# Answer: 'referred to as Jane'
# Answer: '"Amber"'
# Answer: 'is being referred to as Jane'
# Answer: 'her own'
# Answer: 'The teen,'
# Answer: 'no memory of'
# Answer: 'Jane Doe,'
# Question: what is the girl called
# Answer: '"Amber"'
# Answer: 'Jane Doe,'
# Question: Where was the girl found?
# Answer: 'midtown Manhattan'
# Answer: 'Manhattan'
# #######################
# Text: New York (CNN) -- Decades ago, when the Department
# ----------------
# Question: who is anil dash
# Answer: 'opinions expressed in this commentary'
# Answer: 'The opinions expressed in this commentary are solely those of'
# Question: What did Anil Dash say the internet was designed for?
# Answer: 'to be.'
# Answer: 'to have no central point of failure,'
# Question: What does Dash remind us about social networks?
# Answer: 'We've just forgotten a bit'
# Answer: 'how the Internet was supposed to work.'
# #######################
# Text: (CNN) -- A former government contract employee was
# ----------------
# Question: Who is appearing in court?
# Answer: 'Roy Lynn Oakley,'
# Answer: 'Roy Lynn Oakley, 67, of Roane County, Tennessee,'
# Question: Who assigned Oakley the job of breaking machine parts into pieces, and then pitching them?em
# Answer: 'Bechtel Jacobs, the Department of Energy's prime environmental management contractor'
# Question: what did the man do?
# Answer: 'taken from the East Tennessee Technology Park.'
# Answer: 'also charged with converting the material and "restricted data" to his own'
# Answer: 'stealing restricted nuclear'
# Answer: 'energy-related materials'
# Question: what did the man try to do?
# Answer: 'sell'
# Answer: 'sell the "pieces of scrap"'
# Answer: 'stealing restricted nuclear'
# Answer: 'classified material.'
# Answer: 'Oakley attempted'
# Answer: 'divulge the materials,'
# Answer: 'someone he thought was a French agent'
# Answer: 'energy-related materials and putting the United States at risk,'
# Question: Where did the material come from?
# Answer: 'East Tennessee Technology Park.'
# Question: What did Oakley do with the machine part pieces?
# Answer: 'scrap"'
# Answer: 'communicate, transmit and disclose such data to another person."'
# Answer: 'sell'
# Answer: 'attempted to sell the "pieces of scrap" to someone he thought was a French agent'
# Answer: 'stealing restricted nuclear'
# Answer: 'nuclear'
# Answer: 'stealing'
# Answer: 'energy-related materials'
# Question: whats happened in nuclear filter?
# Answer: 'energy officials,'
# Answer: '"barrier"'
# Answer: 'A "barrier" is used to'
# Answer: 'uranium during the enrichment process, according to'
# Answer: 'classified materials were taken'
# Question: Where is Roy Lynn Oakley appearing?
# Answer: 'appeared in federal court in Knoxville'
# Answer: 'federal court in Knoxville'
# Answer: 'federal court'
# Question: what did roy Lyn  in tennessee
# Answer: 'indicted on charges of stealing restricted nuclear'
# Answer: 'energy-related materials and putting the United States at risk,'
# Answer: 'appeared'
# Answer: 'federal court'
# Question: Who appeared in Court in Tennessee?
# Answer: 'Roy Lynn Oakley, 67, of Roane County,'
# Answer: 'Roy Lynn Oakley,'
# Question: What was the facility's role?
# Answer: 'uranium enrichment'
# Question: Who tried to pass nuclear filters?
# Answer: 'Roy Lynn Oakley,'
# Answer: 'Roy Lynn Oakley, 67, of Roane County, Tennessee,'
# Answer: 'Oakley'
# Question: What did the lawyer say?
# Answer: 'Oakley's job was to break rods "into little pieces" and throw them away.'
# Answer: '"Mr. Oakley has cooperated fully for the last six months," said Moncier,'
# Question: What is on the news?
# Answer: 'charges of stealing restricted nuclear'
# Answer: 'and putting the United States at risk, the Department of Justice'
# Answer: 'contract employee was indicted'
# Answer: 'government contract employee was indicted'
# Answer: 'alleged plot to divulge the materials,'
# Answer: 'announced Thursday.'
# Answer: 'government'
# Answer: 'and putting the United States at risk,'
# Answer: 'former'
# Answer: 'A'
# Answer: 'energy-related materials'
# Question: What responsibilities does  Facility's role is to break down decommissioned equipment
# Answer: 'rods "into little pieces" and throw them away.'
# Answer: 'used for the enrichment of uranium."'
# Answer: 'identify rogue employees attempting'
# Answer: 'attempted'
# Answer: 'abuse their access and position."'
# Question: Where did this incident take place?
# Answer: 'East Tennessee Technology Park.'
# Question: What was Oakley's job?
# Answer: 'to break rods "into little pieces" and throw them away.'
# Question: What are the charges for the man who tried to pass nuclear filters to foreign agent?
# Answer: 'stealing restricted'
# Answer: 'energy-related materials and putting the United States at risk,'
# Question: Where did he surrender?
# Answer: 'surrendered'
# Answer: 'FBI field office in Knoxville,'
# Answer: 'at an FBI field office in Knoxville,'
# Answer: 'FBI field office'
# Answer: 'Knoxville,'
# Question: Which state will Roy Lynn Oakley appear in court in?
# Answer: 'Tennessee,'
# Question: Where is Roy Lynn Oakley?
# Answer: 'in Knoxville'
# Answer: 'Roane County, Tennessee,'
# Question: What is the facility's roler?
# Answer: 'hardware used for'
# Answer: 'uranium enrichment through the process of gaseous diffusion'
# Question: What was the man indicted for?
# Answer: 'energy-related'
# Answer: 'on charges of stealing restricted nuclear'
# Answer: 'uranium enrichment through the'
# Answer: 'stealing restricted'
# Answer: 'stealing restricted nuclear'
# Answer: 'nuclear'
# Answer: 'materials'
# Answer: 'having reason to believe that such data would be utilized to injure the United States and secure an advantage to a foreign'
# Answer: 'and putting the United States at risk,'
# Answer: '"having possession of, access to and having been entrusted with sections'
# Answer: 'plot to divulge the materials,'
# Answer: 'of 'barriers' and associated hardware used'
# Answer: 'energy-related materials and putting the United States at risk,'
# Answer: 'nation, did communicate, transmit and disclose such data to another person."'
# Answer: 'process of gaseous diffusion'
# Question: What country was the foreign agent from?
# Answer: 'United States'
# Question: did roy surrender?
# Answer: 'He voluntarily surrendered'
# Question: what is oakley's job?
# Answer: 'break rods'
# Answer: 'was to break rods "into little pieces" and throw them away.'
# Answer: 'to break rods "into little pieces" and throw them away.'
# Question: whats the job of oakley nto pieces?
# Answer: 'was to break rods "into little pieces" and throw them away.'
# #######################
# Text: LONDON, England (CNN)  -- A Web designer in London
# ----------------
# Question: Who is responsible for developing the software that Iranian protesters used to refresh web page to hack official sites?
# Answer: 'Ryan Kelly:'
# Question: What does page reboot software mean?
# Answer: 'that dissidents can "attack" sites with a barrage of hits -- known as a denial of service attack -- causing them to appear to users as "unobtainable."'
# Answer: 'dissidents can "attack" sites with a barrage of hits'
# Answer: 'automatically refreshes a Web page every few seconds,'
# Answer: 'The'
# Answer: 'causing them to appear to users as "unobtainable."'
# Question: quien se trajo ese becerro
# Answer: 'Kelly said he supported the protesters in their battle to have the results of the disputed presidential election overturned.'
# Question: what forced ryan kelly to temporarily suspend it?
# Answer: 'heavy traffic'
# Question: What kind of site did the iranian protesters use?
# Answer: 'that automatically refreshes a Web page every few seconds, potentially overloading the host server.'
# Answer: 'like Facebook and Twitter,'
# Answer: 'president's Web'
# Answer: 'a'
# Question: What is actually happens to a web site when page reboot software sends a barrage of hits to it?
# Answer: 'causing them'
# Answer: 'users as "unobtainable."'
# Answer: 'appear'
# Question: At what time did Ryan Kelly restore the sites after temporarily suspending them?
# Answer: 'his spare'
# #######################
# Text: London (CNN) -- Personal details about Tony Blair
# ----------------
# Question: What did Tony Blairs spokesman say?
# Answer: 'or any of his office systems."'
# Answer: '"This information has not been obtained from'
# Question: What is the name of the hacker group ?
# Answer: 'TeaMp0isoN'
# Question: what did team poison say about the information
# Answer: 'getting leaked tonight,'
# Answer: '"doing the writeup now - Tony Blair and his cockroaches are getting owned tonight. - War IS Terror."'
# Answer: '"Tony Blair's Private Info'
# Question: What information was stolen?
# Answer: 'Personal details about Tony Blair'
# Question: what did he say about the details
# Answer: 'not hacked'
# Answer: 'Personal'
# Answer: 'were apparently not hacked from'
# Answer: 'account of a former staffer.'
# Answer: 'the former British prime minister's computer systems, but from the email'
# Answer: 'Tony Blair'
# Answer: '"This information has not been obtained from Tony Blair or any of his office systems."'
# Question: What does it appear to give
# Answer: 'information from the personal email account of a former member of staff from a few years ago,"'
# Answer: 'and the addresses and phone numbers of numerous personal contacts.'
# Answer: 'Blair's National Insurance number'
# #######################
# Text: (CNN)  -- Top Republican lawmakers Sunday called o
# ----------------
# Question: What did the spokesman say about the President?
# Answer: 'Republicans.'
# Answer: 'John McCain'
# Answer: 'unprecedented effort to reach out'
# Answer: 'you saw from'
# Answer: 'was'
# Question: Amount of money that the bill is worth?
# Answer: '$787 billion'
# Question: What did Congress pass?
# Answer: 'a massive stimulus bill'
# Answer: 'massive stimulus bill'
# Question: Who will sign the bill on Tuesday?
# Answer: 'Top Republican lawmakers'
# Answer: 'President Obama'
# Answer: 'Obama'
# Question: What is Obama expected to do on Tuesday?
# Answer: 'change his political strategy,'
# Answer: 'sign the bill'
# Question: What did the Senators say about the bill?
# Answer: 'on a party-line vote showed he has failed to deliver the "change" he promised.'
# Answer: 'arguing that the passage of a massive stimulus'
# Answer: '"This is not 'change we can believe in,''
# Question: What did McCain and Graham say about the stimulus bill?
# Answer: '"bad beginning."'
# Answer: 'American'
# Answer: 'would sit down together,"'
# Answer: 'bad beginning because'
# Answer: 'President Obama promised'
# Answer: 'told CNN's'
# Answer: 'wasn't'
# Answer: 'the country's screwed,"'
# Answer: 'we promised the American people,'
# Answer: 'that'
# Question: When is Obama expected to sign the bill?
# Answer: 'Tuesday'
# Question: Who said the stimulus bill wasn't bipartisan?
# Answer: 'Top Republican lawmakers'
# Answer: 'John McCain,'
# Answer: 'Sen. Lindsey Graham,'
# Question: What did the spokesman say?
# Answer: 'White House'
# Answer: '"We're happy that Congress, in a bipartisan way, took steps to make whatever happens in this recession easier to take for the American people."'
# Answer: 'Robert Gibbs said, "We're happy that Congress, in a bipartisan way, took steps to make whatever happens in this recession easier to take for the American people."'
# Question: How many Republicans supported the bill?
# Answer: 'three'
# #######################
# Text: WASHINGTON (CNN) -- Former ABC News chief national
# ----------------
# Question: Was he wearing a helmet?
# Answer: 'McWethy'
# Answer: 'a'
# Question: Who died in Colorado ski accident?
# Answer: 'John McWethy'
# Question: Who was wearing a helmet?
# Answer: 'McWethy'
# Answer: 'John McWethy,'
# Question: For how long was he a reporting?
# Answer: 'nearly 30 years'
# Question: Who is the ABC president?
# Answer: 'David Westin.'
# Question: What caused him to die?
# Answer: 'injuries'
# Answer: 'in a Colorado skiing accident,'
# Question: What did he love to do?
# Answer: 'ski'
# Answer: 'enjoy Colorado's ski trails,'
# Answer: 'Colorado's ski trails,'
# Question: Reporter died doing "something he truly loved," says ABC president
# Answer: 'something that'
# Answer: 'Weston said.'
# Question: Who died in a ski accident?
# Answer: 'John McWethy'
# Question: What was the reporter doing?
# Answer: 'skiing'
# Answer: 'lost control and slammed into a tree,'
# Answer: 'skiing fast on an intermediate trail'
# #######################
# Text: LOS ANGELES, California (CNN) -- Fans wishing to a
# ----------------
# Question: Who has  joined inquiry into Jackson's death?
# Answer: 'family'
# Answer: 'The Drug Enforcement Administration'
# Question: Where will the memorial take place?
# Answer: 'at Neverland Ranch.'
# Answer: 'Neverland Ranch.'
# Answer: 'Staples Center in Los Angeles, California,'
# Answer: 'the'
# Question: How many days before Jackson's death was the video taken?
# Answer: 'two'
# Answer: 'his'
# Answer: 'he died,'
# Answer: 'two nights'
# Question: Where will Jackon's memorial be?
# Answer: 'Los Angeles, California,'
# Answer: 'Staples Center'
# Answer: 'Staples Center in Los Angeles,'
# Question: Who joins the inquiry into Jackson's death?
# Answer: 'look at doctors involved with'
# Answer: 'The Drug Enforcement Administration'
# Question: How many service tickets will be made available?
# Answer: '20,000-seat'
# Answer: '11,000'
# Question: How many memorial service tickets will be made available?
# Answer: '11,000'
# Question: Whose memorial will be Tuesday?
# Answer: 'Michael Jackson's'
# #######################
# Text: Washington (CNN) -- The stars were out Sunday nigh
# ----------------
# Question: Who called the award legimate?
# Answer: 'Ferrell'
# Answer: 'Will Ferrell.'
# Question: What for comedians are honored by award?
# Answer: 'who have shaped American society with their work,'
# Answer: 'Jack Black, Tim Meadows, Ed Asner, Paul Rudd,'
# Question: Who does the award honor?
# Answer: 'have shaped American society'
# Answer: 'comedians'
# Question: What did Ferrell say about the award?
# Answer: '"the only legitimate'
# Answer: 'it's "the only legitimate'
# Answer: 'that recognizes comedy," and he was honored to receive it.'
# Answer: 'that recognizes comedy,"'
# Answer: 'only legitimate'
# Question: What was fellow comedians reaction on Ferrell saying?
# Answer: 'with praise at the ceremony.'
# Answer: 'showered'
# Answer: 'with praise'
# #######################
# Text: (CNN) -- Henry Joseph Madden was a good student an
# ----------------
# Question: What do doctors speculate?
# Answer: 'in the biological makeup determines that gender.'
# Answer: 'that there is a biological foundation to gender identity,'
# Answer: 'that there is a biological foundation to gender identity, but no one has determined'
# Question: What do people rarely undergo?
# Answer: 'a gender transition and then want to reverse it,'
# Answer: 'a gender transition and then want to reverse it, especially when surgery is involved,'
# Answer: 'to'
# Answer: 'rare for'
# Question: What is the estimated percentage of transgendered Americans?
# Answer: '0.25 to 0.5 percent of the'
# Answer: '0.25 to 0.5 percent'
# Answer: 'population is'
# Question: What is the percentage of transgender Americans?
# Answer: '0.25 to 0.5 percent'
# Question: What types of people would want to reverse a gender-reassignment surgery?
# Answer: 'Transgendered individuals'
# Question: What do doctors speculate as the reason for gender identity?
# Answer: 'there is a biological foundation to'
# Answer: 'biological foundation to'
# Question: What surgery do people undergo and then rarely want to reverse?
# Answer: 'gender transition'
# Question: What proportion of the American population is transgendered?
# Answer: 'one advocate estimates that 0.25 to 0.5 percent of the'
# Answer: 'estimates that 0.25 to 0.5 percent of the'
# Answer: '0.25 to 0.5 percent'
# Answer: 'is'
# Question: Biological foundation is an influence to what?
# Answer: 'gender identity,'
# #######################
# Text: BOGOTA, Colombia (CNN) -- A key rebel commander an
# ----------------
# Question: Who managed the drug ring?
# Answer: 'helped manage the group's extensive cocaine trafficking network.'
# Answer: 'U.S. officials alleged Medina Caracas'
# Answer: 'Tomas Medina Caracas'
# ...
# Answer: 'jail'
# Answer: 'forcing'
# Answer: 'of checking male'
# Answer: 'not assault them.'
# Answer: 'he hugged'
# Answer: 'engage'
# Answer: 'was found not guilty Monday on charges of sexual abuse, attempted sodomy'
# Answer: '"He hugged me and'
# Answer: 'trying to mentor the inmates and'
# Answer: 'supporters. It all worked out'
# Answer: 'A'
# Answer: 'law license back,"'
# Answer: 'judge accused of checking male inmates'
# Answer: 'and'
# Answer: 'former Judge Herman Thomas was found not guilty on several charges and the judge in the case granted a directed verdict of acquittal on all the other counts.'
# Answer: 'accused'
# Answer: 'was found not guilty Monday on charges of sexual abuse, attempted sodomy and assault,'
# Answer: 'in the end,"'
# Answer: 'on October 20 that the judge was'
# Answer: '"He was'
# Answer: 'cried after the verdicts were read,'
# Answer: 'Thomas'
# Answer: 'Thomas cried after the verdicts were read,'
# Answer: 'them'
# Answer: 'to'
# Answer: 'of'
# Answer: 'inmates'
# Answer: 'bringing the inmates into'
# Answer: '"They suspended him back in March because he got indicted. And we're fighting to give him'
# Answer: 'judge'
# Answer: 'office,'
# Answer: '"He was mentoring them. He was trying to get them to do right, to be productive citizens."'
# Answer: 'mentoring them. He was trying to get them to do right,'
# Answer: 'client's next hurdle is the Alabama State Bar.'
# Answer: 'The judge does not deny'
# Question: Who did the judge bring to his office?
# Answer: 'inmates'
# Question: Who was acquitted of sexual abuse?
# Answer: 'former Judge Herman Thomas'
# Answer: 'Judge Herman Thomas'
# Answer: 'Herman Thomas'
# Question: What the lawyer said?
# Answer: 'and assault,'
# Answer: 'Alabama'
# Answer: 'in sexual activity'
# Answer: 'former Judge Herman Thomas was found not guilty on several charges and the judge in the case granted a directed verdict of acquittal on all the other counts.'
# Answer: 'judge accused of checking male inmates out of jail and forcing them to engage'
# Answer: 'was found not guilty Monday on charges of sexual abuse, attempted sodomy'
# Answer: 'former'
# Answer: 'A'
# Question: What kind of citizens did the judge want them to become?
# Answer: 'be productive citizens."'
# Answer: 'productive'
# Question: What the judge said?
# Answer: 'guilty'
# Answer: 'found'
# Answer: 'several charges'
# Answer: '"He was mentoring them.'
# Answer: 'Thomas'
# Question: What was accused Herman Thomas?
# Answer: 'of checking male inmates out of jail and forcing them to engage'
# Answer: 'assault,'
# Answer: 'in sexual activity'
# Answer: 'former Alabama judge'
# Answer: 'sexual abuse, attempted sodomy'
# Answer: 'A'
# #######################
# Text: (CNN)  -- A man who rescued a co-worker from the j
# ----------------
# Question: The two were collecting crocodile eggs by a river bank in the Northern Territory
# Answer: 'Darwin'
# Answer: 'Adelaide'
# Question: what Wounded man's injuries?
# Answer: 'also accidentally'
# Answer: 'shot him in the process,'
# Answer: 'jaws of a crocodile'
# Question: He shot crocodile, causing it to let go of man's arm, second shot hit man's arm
# Answer: 'Zac Fitzgerald,'
# Question: The second shot hit what?
# Answer: 'struck Grant'
# Answer: 'upper right arm,'
# Answer: 'struck Grant in the upper right arm,'
# Question: what He shot crocodile?
# Answer: 'Zac Fitzgerald,'
# Answer: 'the'
# Question: The man was rescued from what in northern Australia?
# Answer: 'the jaws of a crocodile'
# Question: The men were collecting what on the river bank in the Northern Territory?
# Answer: 'crocodile eggs'
# Question: where Man rescues co-worker?
# Answer: 'northern Australia'
# Answer: 'jaws of a crocodile in northern Australia'
# Question: Did the crocodile die as a result of being shot?
# Answer: 'His injuries were not life-threatening,'
# #######################
# Text: A Nigerian politician has been arrested for trying
# ----------------
# Question: What was the smuggler trying to finance?
# Answer: 'election campaign,'
# Question: What did the politician try to smuggle?
# Answer: 'five pounds of cocaine'
# Question: Authorities said he was trying to finance what ?
# Answer: 'his election campaign,'
# Answer: 'election campaign,'
# Question: Who tried to smuggle cocaine in his stomach?
# Answer: 'Eme Zuru Ayortor,'
# Question: What did Eme Zuru Ayortor say?
# Answer: 'told authorities that he was hoping his status as a politician would help him avoid being arrested.'
# Answer: 'he was hoping his status as a politician would help him avoid being arrested.'
# Question: What politician tried to smuggle almost five pounds of cocaine in his stomach ?
# Answer: 'Eme Zuru Ayortor,'
# Answer: 'Nigerian'
# Question: Who told officials he thought his status as a politician would help him?
# Answer: 'Ayortor,'
# Answer: 'The suspect'
# Answer: 'suspect'
# Question: What did the authorities say?
# Answer: 'finance his election campaign,'
# Answer: 'in a scheme to'
# Answer: 'Nigerian'
# Answer: 'arrested for trying to smuggle almost five pounds of cocaine in his stomach'
# Answer: 'A'
# Answer: 'has been'
# Answer: 'politician'
# Question: Who told officials he thought his status as politician would help him avoid arrest ?
# Answer: 'Eme Zuru Ayortor,'
# #######################
# Text: (CNN) -- Explorer Dennis Schmitt found an island n
# ----------------
# Question: What has warmed one degree?
# Answer: 'average surface temperature'
# Answer: 'The Earth's'
# Answer: 'surface temperature'
# Answer: 'The average surface temperature'
# Answer: 'surface'
# Question: What do majority of scientists say greenhouse gases cause?
# Answer: 'global warming.'
# Answer: 'global warming'
# Question: what are planets often in according to some critcs?
# Answer: 'goes through phases of warming and cooling and the human contribution'
# Answer: 'life.'
# Answer: 'global warming."'
# Answer: 'the cyclical patterns of a'
# Answer: 'it is minimal.'
# Answer: 'Greenland.'
# Answer: 'natural variability, where a'
# Question: who cares about greenhouse gas?
# Answer: 'Dennis Schmitt'
# Question: what temperature has earth warmed by in past 100 years?
# Answer: 'one degree Fahrenheit'
# Answer: 'one degree Fahrenheit (0.6 degrees Celsius) during the last century, according to the National Research Council.'
# Answer: 'The average surface'
# Answer: 'one degree Fahrenheit (0.6 degrees Celsius)'
# Question: In past 100 years by what number of degrees has the Earth warmed
# Answer: 'Fahrenheit (0.6'
# Answer: 'one'
# Answer: 'Fahrenheit'
# Answer: 'Celsius)'
# Question: What has happened to the Earth?
# Answer: '"The'
# Answer: '"It's always changing. In fact, this is true of any fluid-covered planet."'
# Answer: 'is always getting colder and warmer,"'
# Answer: 'global warming.'
# Question: Who says planets are warming or cooling?
# Answer: 'Explorer'
# Answer: 'Dennis Schmitt'
# Question: What do a majority of scientists say is causing temperatures to rise.
# Answer: 'change in the Earth's orbit or the intensity of the sun's radiation could change, triggering warming or cooling.'
# Answer: 'result of human activities, like the burning'
# Answer: 'increase in the concentrations of greenhouse gases,'
# Answer: 'arctic ice melt and other changes in the Earth's climate are the result of an increase in the world's'
# Answer: 'global warming.'
# Answer: 'presence of methane'
# Answer: 'fossil fuels, emissions from vehicles and the clearing of forests.'
# Answer: 'a trend widely called global warming.'
# Answer: 'an increase in the concentrations of greenhouse gases,'
# Answer: 'now 151 percent above pre-industrial levels,'
# Answer: 'simply the latest shift in the cyclical patterns of a planet's life.'
# Question: What do some critics say about planets often having?
# Answer: 'goes through phases of warming and cooling'
# Answer: 'natural variability,'
# Answer: 'climate change."'
# Answer: 'global warming'
# Question: what do the majority of scientists blame for rising temperatures?
# Answer: 'increase is primarily the result of human activities, like the burning of fossil fuels, emissions from vehicles and the clearing of forests.'
# Answer: 'increase in the concentrations of greenhouse gases,'
# Answer: 'intensity of the sun's radiation'
# Answer: 'the result of an increase in the world's'
# Answer: 'several possible reasons'
# Answer: 'change in the Earth's orbit'
# Answer: 'humans are at least a'
# Answer: 'an increase in the concentrations of greenhouse gases,'
# Answer: 'a trend widely called global warming.'
# Question: By how many degree Earth has warmed up in last 100 years?
# Answer: 'one'
# Answer: 'Fahrenheit'
# Question: What are critics saying?
# Answer: 'a planet's life.'
# Answer: 'latest shift'
# Answer: 'the cyclical patterns'
# Question: What are causing temperatures to rise?
# Answer: 'trend widely called global warming.'
# Answer: 'increase in the concentrations of greenhouse gases,'
# Question: Who says something about planets?
# Answer: 'by scientists and scientific organizations'
# Question: What causes temperatures to rise?
# Answer: 'global warming.'
# Question: What do scientists say is causing the temperatures to rise?
# Answer: 'primarily the result of human activities,'
# Answer: 'greenhouse gases,'
# Answer: 'Many climatologists and'
# Answer: 'scientific'
# Answer: 'atmosphere'
# Answer: 'increase in the world's'
# Answer: 'an increase in the concentrations of greenhouse gases, which are in the atmosphere naturally and help keep the planet's'
# Answer: 'reason most'
# Answer: 'concentrations'
# Answer: 'arctic ice melt and other changes in the Earth's climate are the result of an increase in the world's'
# Answer: 'global warming.'
# Answer: 'current warming trend'
# Answer: 'an increase'
# Answer: 'burning of fossil fuels, emissions from vehicles and the clearing of forests.'
# Answer: 'increase'
# Answer: 'world's'
# Answer: 'at a comfortable level.'
# Question: What are often in periods of warming or cooling according to critics?
# Answer: 'and'
# Answer: 'change'
# Answer: 'planet goes through phases of'
# Answer: 'Island.'
# Answer: 'Earth's orbit'
# Question: Who is talking about greenhouse gasses?
# Answer: 'climatologists'
# Answer: 'scientists and scientific organizations'
# Answer: 'scientists'
# Answer: 'Dennis Schmitt'
# Question: By how much has the earth warmed in the last 100 years?
# Answer: 'one degree Fahrenheit'
# Answer: 'average surface temperature'
# Answer: 'surface temperature'
# Answer: 'during the'
# Answer: 'century,'
# Answer: 'one degree Fahrenheit (0.6 degrees Celsius) during the'
# Question: What has warmed one degree in 100 years?
# Answer: 'an island'
# Answer: 'average surface temperature'
# Answer: 'during the last century,'
# Answer: 'The Earth's'
# Question: What do critics say planet his periods of?
# Answer: 'arctic ice melt'
# Question: What do critics say?
# Answer: 'skeptics is Richard Lindzen,'
# Question: What has the Earth warmed in the past 100 years?
# Answer: 'one degree Fahrenheit'
# Answer: 'global'
# Answer: 'world's temperature,'
# Question: What is causing temperature to rise?
# Answer: 'an increase in the concentrations of greenhouse gases,'
# Question: What has warmed up one degree?
# Answer: 'average surface temperature'
# Question: What are greenhouse gases causing?
# Answer: 'colder'
# Answer: 'warmer,"'
# Answer: 'global warming.'
# #######################
# Text: KABUL, Afghanistan (CNN)  -- Two coalition U.S. so
# ----------------
# Question: What killed the five people?
# Answer: 'roadside bomb'
# Question: Who were they accompanying?
# Answer: 'part of a convoy of coalition troops'
# Answer: 'The soldiers'
# Answer: 'Gulab Mangal,'
# Answer: 'Gulab Mangal, the governor of Helmand province,'
# Answer: 'governor of Helmand province,'
# Question: What did the soldiers try to do?
# Answer: 'disable a roadside bomb'
# Answer: 'explosion'
# Answer: 'disable the bombs,'
# Question: Who were the soldiers accompanying in the convoy?
# Answer: 'three Afghans,'
# Answer: 'Helmand'
# Answer: 'governor'
# Answer: 'Gulab Mangal,'
# Answer: 'Gulab Mangal, the governor of Helmand province,'
# Question: Who was killed?
# Answer: 'three Afghans,'
# Answer: 'police chief'
# Answer: 'Two coalition U.S. soldiers'
# Question: What did soldiers do?
# Answer: 'tried to disable the bombs,'
# Question: Where were the two soldiers from who were killing by the roadside bomb?
# Answer: 'southern Afghanistan'
# Answer: 'coalition U.S.'
# Answer: 'U.S.'
# Question: Who were the soldiers accompanying?
# Answer: 'Gulab Mangal,'
# #######################
# Text: (CNN) -- He's gone from being a backup dancer to t
# ----------------
# Question: Who will appear on Talk Asia?
# Answer: 'Rain, real name Jung Ji-hoon,'
# Answer: 'Rain'
# Question: What will Rain be answering?
# Answer: 'questions.'
# Question: Where is former backup dancer appearing now?
# Answer: 'alongside Christina Ricci and Matthew Fox.'
# Answer: 'Hollywood'
# Question: who will answer questions
# Answer: 'Rain, real name Jung Ji-hoon,'
# Answer: 'recently he faced your'
# Answer: 'singer'
# Answer: 'Watch the show and find out what makes Rain tick'
# Answer: 'Rain'
# Question: what country is he from?
# Answer: 'South Korean'
# Answer: 'gone'
# Answer: 'being a backup dancer to the biggest thing in Asian'
# Question: who will be answering questions?
# Answer: 'Rain, real name Jung Ji-hoon,'
# Answer: 'recently he faced your'
# #######################
# Text: WASHINGTON (CNN)  -- The Bush administration haile
# ----------------
# Question: what is the reasoning behind this?
# Answer: 'North Korea, which is isolated and desperately in need of international aid,'
# Question: Who says the Bush administration has let Pyongyang off the hook?
# Answer: 'Congressional Republicans'
# Answer: 'conservative Republicans.'
# Question: what does it say or not say?
# Answer: 'where they are hidden. Nor did North Korea admit to'
# Answer: 'is'
# Answer: 'is no mention of how'
# Answer: 'There is no mention of how'
# Answer: 'nuclear secrets'
# Answer: 'may have shared with Syria. Both issues'
# Answer: 'doesn't'
# Answer: 'many weapons North Korea has'
# Answer: 'suspected uranium enrichment program'
# Answer: 'where they are hidden.'
# Answer: 'reduced'
# Question: North Korea didn't admit to uranium enrichment or sharing secrets with Syria
# Answer: 'shared'
# Answer: 'Nor did'
# Answer: 'nuclear'
# Question: Who may be headed down the same road with Iran?
# Answer: 'United States'
# Answer: 'North Korea'
# Answer: 'U.S.'
# Question: What didn't North Korea admit to?
# Answer: 'nuclear secrets it may have shared with Syria.'
# Answer: 'nuclear secrets'
# Answer: 'suspected uranium enrichment program or'
# Answer: 'shared with Syria.'
# Answer: 'suspected uranium enrichment program'
# Question: What did North Korea not admit to?
# Answer: 'There is no mention of how'
# Answer: 'nuclear secrets it may have shared with Syria.'
# Answer: 'a suspected uranium enrichment program or'
# Answer: 'many weapons North Korea has or where they are hidden. Nor did North Korea admit to a suspected uranium enrichment program or what nuclear secrets it may have shared with Syria. Both issues are reduced in the declaration to "concerns" Pyongyang promises to address down the road.'
# Question: What is just as important?
# Answer: 'how'
# Answer: 'many weapons North Korea has or where they are hidden.'
# Answer: 'doesn't say.'
# Answer: 'it doesn't say.'
# Answer: 'document'
# Question: Who has been let off the hook?
# Answer: 'North Korea'
# Answer: 'Bush administration'
# Answer: 'the'
# #######################
# Text: (CNN) -- The nation's new "first dog" has heighten
# ----------------
# Question: What dog breed is described as "active athletes"?
# Answer: 'from couch potatoes, she explained.'
# Answer: 'are'
# Answer: 'athletes," far from couch potatoes, she explained.'
# Answer: 'Portuguese water'
# Answer: 'athletes,"'
# Question: What do dogs bond quickly with?
# Answer: 'Portuguese water'
# Question: What are Portugese water dogs like?
# Answer: 'are "active athletes," far from couch potatoes,'
# Answer: '"active athletes," far from couch potatoes, she explained.'
# Answer: 'Portuguese'
# Question: Who is more likely to rip up the couch, than lounge on it?
# Answer: 'Portuguese water dogs'
# Question: What issue is the breeders concerned about?
# Answer: 'thorough understanding of the dogs' needs,'
# Answer: 'a thorough understanding of the dogs' needs,'
# Question: Who is Bo the dog?
# Answer: 'a gift to the Obama girls'
# Answer: 'gift to the Obama girls from Sen. Ted Kennedy.'
# #######################

# %%
print(f"Numbers of articles: {len(extracted_data)}")
# Out:
# Numbers of articles: 200

# %% [markdown]
# # Save file

# %%
with open('./data/evaluation_data.txt', 'w', encoding='utf-8') as output_file:
    for item in extracted_data:
        output_file.write(f"{json.dumps(item)}\n")

# %% [markdown]
# # Save individual stories

# %%
import os

def save_all_stories(save_location, extracted_data):
    """Save all story texts from extracted_data to separate txt files."""
    # Create a directory for saving stories if it doesn't exist
    os.makedirs(f"{save_location}/stories", exist_ok=True)
    
    for index, story in enumerate(extracted_data):
        text = story.get("text", "").strip()  # Get the story text
        
        # Define the filename based on the index
        filename = f'{save_location}/stories/url_{index + 1}.txt'  # Adding 1 to start from 1 instead of 0
        with open(filename, 'w', encoding='utf-8') as file:
            file.write(text)
save_location = "./data"
save_all_stories(save_location, extracted_data)

# %% [markdown]
# # Load file

# %%
import json

# Path to your text file
data_file = "./data/evaluation_data.txt"

# Function to read and extract the "text" value from each line
def extract_text_values(file_path):
    text_values = []  # List to store the "text" values
    with open(file_path, "r") as file:
        for line in file:
            try:
                # Parse the JSON string into a dictionary
                json_data = json.loads(line)
                # Extract the "text" value and append it to the list
                text_values.append(json_data["text"])
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON: {e}")
            except KeyError as e:
                print(f"Key error: {e}")
    return text_values

# Call the function and get the "text" values
text_list = extract_text_values(data_file)

# Print the extracted text values
for index, text in enumerate(text_list):
    print(f"{index}: {text[:20]}")  # Print the first 20 characters of each text
# Out:
# 0: NEW DELHI, India (CN
# 1: (CNN) -- Fighting in
# 2: Johannesburg (CNN) -
# 3: (CNN)  -- England in
# 4: BAGHDAD, Iraq (CNN)
# 5: (CNN) -- Pope John P
# 6: CNN affiliates repor
# 7: WASHINGTON (CNN) --
# 8: TEHRAN, Iran (CNN) -
# 9: (CNN) -- Jewish orga
# 10: (CNN) -- A phone hac
# 11: ATLANTA, Georgia (CN
# 12: Berlin, Germany (CNN
# 13: SAVANNAH, Georgia (C
# 14: (CNN) -- Les Paul ne
# 15: United Nations (CNN)
# 16: BOSTON, Massachusett
# 17: (CNN Student News)
# 18: UNITED NATIONS (CNN)
# 19: (CNN) -- Barcelona m
# 20: BAGHDAD, Iraq (CNN)
# 21: (CNN) -- Two goals i
# 22: WASHINGTON (CNN) --
# 23: (CNN)  -- When Kello
# 24: (CNN) -- Kyrgyzstan'
# 25: Cleveland, Ohio (CNN
# 26: NEW YORK (CNN)  -- A
# 27: New York (CNN) -- De
# 28: (CNN) -- A former go
# 29: LONDON, England (CNN
# 30: London (CNN) -- Pers
# 31: (CNN)  -- Top Republ
# 32: WASHINGTON (CNN) --
# 33: LOS ANGELES, Califor
# 34: Washington (CNN) --
# 35: (CNN) -- Henry Josep
# 36: BOGOTA, Colombia (CN
# 37: (CNN) -- Authorities
# 38: LONDON, England (CNN
# 39: COLOMBO, Sri Lanka (
# 40: (CNN) -- Fashion des
# 41: (CNN) -- A thin girl
# 42: (CNN) -- Police have
# 43: (CNN) -- Insurgents
# 44: (CNN) -- Icelandic P
# 45: (CNN) -- British box
# 46: (CNN) -- Verizon has
# 47: BUENOS AIRES, Argent
# 48: (CNN) -- Ferrari pre
# 49: ISLAMABAD, Pakistan
# 50: (CNN) -- Coming back
# 51: (CNN) -- A Californi
# 52: (CNN) -- After meeti
# 53: (CNN) -- Panama City
# 54: SAN MIGUEL DEL MONTE
# 55: (Entertainment Weekl
# 56: (CNN) -- Comcast rol
# 57: (CNN) -- Volcanologi
# 58: (CNN) -- Israeli Pre
# 59: (CNN) -- Arsenal cli
# 60: (CNN) -- NASA scient
# 61: (CNN) -- "It was boo
# 62: (CNN) -- A 14-year-o
# 63: LONDON, England (CNN
# 64: (CNN) -- Missing Flo
# 65: Willow, Alaska (CNN)
# 66: (CNN) -- William Bea
# 67: TEHRAN, Iran (CNN) -
# 68: Princeton, New Jerse
# 69: (CNN) -- A Maryland
# 70: NEW DELHI, India (CN
# 71: ISLAMABAD, Pakistan
# 72: (CNN) -- The power o
# 73: New York (CNN) -- Wh
# 74: (CNN) -- Famed Urugu
# 75: PHOENIX, Arizona (CN
# 76: (CNN) -- What could
# 77: Editor's note: Lesli
# 78: (EW.com) -- Although
# 79: TEHRAN, Iran (CNN) -
# 80: LOS ANGELES, Califor
# 81: (CNN) -- Civilians a
# 82: (CNN) -- U.S. Air Fo
# 83: (CNN) -- Chinese lan
# 84: LOS ANGELES, Califor
# 85: (CNN) -- German car
# 86: (CNN) -- Bayer Lever
# 87: BAGHDAD, Iraq (CNN)
# 88: (CNN)  -- Buy a $175
# 89: LOS ANGELES, Califor
# 90: (CNN) -- Most conser
# 91: (CNN) -- It's that t
# 92: COLUMBIA, South Caro
# 93: WASHINGTON (CNN) --
# 94: (CNN) -- A pair of e
# 95: (CNN) -- Griffin Bel
# 96: New York (CNN) -- Li
# 97: PARIS, France -- AC
# 98: (CNN) -- Zambia's in
# 99: (CNN) -- Sen. Barack
# 100: (CNN) -- Dubai could
# 101: ORME, Tennessee (CNN
# 102: (CNN) -- Eddie Murph
# 103: Editor's note: Campb
# 104: NEW ORLEANS, Louisia
# 105: LONDON, England (CNN
# 106: (CNN) -- AC Milan co
# 107: WASHINGTON (CNN) --
# 108: (CNN) -- A court in
# 109: NEW YORK (CNN)  -- T
# 110: (CNN) -- The Catholi
# 111: (CNN) -- Paul Harvey
# 112: (CNN) -- Some Democr
# 113: (CNN) -- NASA won't
# 114: DENVER, Colorado (CN
# 115: (CNN) -- A federal i
# 116: LONDON, England (CNN
# 117: (CNN) -- Searchers h
# 118: LONDON, England (CNN
# 119: (CNN) -- Decorating
# 120: Islamabad, Pakistan
# 121: WASHINGTON (CNN) --
# 122: (CNN) -- Police have
# 123: (CNN) -- We have a t
# 124: Washington (CNN) --
# 125: WASHINGTON (CNN)  --
# 126: (CNN)  -- Rescuers h
# 127: JOHANNESBURG, South
# 128: (CNN) -- Comedian Ge
# 129: INDIO, California (C
# 130: JOHANNESBURG, South
# 131: NAPLES, Florida (CNN
# 132: Sara, 29, has lived
# 133: (CNN)  -- The man ar
# 134: (CNN) -- A British-o
# 135: (CNN) -- The partner
# 136: (CNN) -- Neda Agha-S
# 137: MUMBAI, India (CNN)
# 138: BAGHDAD, Iraq (CNN)
# 139: (CNN)  -- The widow
# 140: (CNN) -- In the thre
# 141: NEW DELHI, India (CN
# 142: (CNN) -- U.S. Presid
# 143: (CNN) -- A lawyer wh
# 144: (CNN)  -- Hundreds o
# 145: (CNN) -- Ferrari pre
# 146: (CNN) -- Perhaps it
# 147: Islamabad, Pakistan
# 148: (CNN) -- Pakistan's
# 149: LONDON, England (CNN
# 150: (CNN) -- Tareq Salah
# 151: EL PASO, Texas (CNN)
# 152: NEW YORK (CNN) -- Pf
# 153: NEW YORK (CNN) -- Co
# 154: (CNN) -- Retired Adm
# 155: WASHINGTON (CNN)  --
# 156: TEHRAN, Iran (CNN) -
# 157: WASHINGTON (CNN) --
# 158: (CNN) -- World-recor
# 159: (CNN) -- When Barack
# 160: (CNN) -- Dubai could
# 161: (CNN) -- Researchers
# 162: BAGHDAD, Iraq (CNN)
# 163: Baltimore, Maryland
# 164: FARGO, North Dakota
# 165: NEW YORK (CNN) -- Co
# 166: LONDON, England (CNN
# 167: NEW YORK (CNN)  -- O
# 168: BEIRUT, Lebanon (CNN
# 169: (CNN) -- Chris Helmb
# 170: (EW.com) -- Enough w
# 171: KABUL, Afghanistan (
# 172: WASHINGTON (CNN) --
# 173: SAN FRANCISCO, Calif
# 174: LOS ANGELES, Califor
# 175: KABUL, Afghanistan (
# 176: (CNN) -- Farrah Fawc
# 177: (CNN) -- A former "M
# 178: (CNN) -- Liverpool a
# 179: LONDON, England (CNN
# 180: (CNN) -- The first p
# 181: Cancun, Mexico (CNN)
# 182: (CNN) -- Doctors cho
# 183: (CNN) -- The flu has
# 184: LONDON, England (CNN
# 185: (CNN) -- The head of
# 186: Editor's note: Journ
# 187: (CNN) -- A drunk pas
# 188: (CNN) -- A federal a
# 189: LOS ANGELES, Califor
# 190: (CNN) -- Union worke
# 191: Seoul, South Korea (
# 192: ATLANTA, Georgia --
# 193: (CNN Student News) -
# 194: LOS ANGELES, Califor
# 195: BREMEN, Germany -- C
# 196: QUANTICO, Virginia (
# 197: (CNN) -- In Mexico C
# 198: (CNN) -- Speculation
# 199: Tehran, Iran (CNN) -
# 200: ATLANTA, Georgia (CN
# 201: (CNN) -- A Colorado
# 202: (CNN) -- Based on a
# 203: (Entertainment Weekl
# 204: (CNN)  -- It's a tri
# 205: WASHINGTON (CNN) --
# 206: (CNN) -- Americans a
# 207: (CNN) -- New sprint
# 208: WASHINGTON (CNN) --
# 209: MIAMI, Florida (CNN)
# 210: Editor's note: CNN c
# 211: (CNN) -- German bill
# 212: (CNN) -- Gennaro Gat
# 213: L'AQUILA, Italy (CNN
# 214: (CNN) -- Women in So
# 215: WASHINGTON (CNN) --
# 216: EVERETT, Washington
# 217: (CNN) -- Incumbent l
# 218: Dhaka, Bangladesh (C
# 219: (CNN) -- Iran's supr
# 220: (CNN) -- Clouds of b
# 221: LONDON, England (CNN
# 222: (Budget Travel) -- O
# 223: (CNN) -- Spongy red
# 224: MEXICO CITY, Mexico
# 225: (CNN)  -- President
# 226: (CNN) -- We are losi
# 227: (CNN) -- The Cannes
# 228: (CNN) -- Former Phil
# 229: (Mental Floss) -- If
# 230: (CNN)  -- The entire
# 231: (CNN) -- Barack Obam
# 232: WASHINGTON (CNN) --
# 233: Los Angeles (CNN) --
# 234: (CNN) -- Olafur Ragn
# 235: (CNN) -- It was just
# 236: NEW YORK (CNN) -- As
# 237: London, England (CNN
# 238: (CNN) -- North Korea
# 239: Khartoum, Sudan (CNN
# 240: LAHORE, Pakistan (CN
# 241: (CNN) -- Fans of the
# 242: (CNN) -- Scotland's
# 243: (CNN) -- It's all ti
# 244: (CNN) -- Bayern Muni
# 245: ATHENS, Georgia (CNN
# 246: Editor's note: We as
# 247: (CNN) -- A Seattle m
# 248: (CNN) -- Two people
# 249: (CNN) -- When 3-year
# 250: LOS ANGELES, Califor
# 251: (Travel + Leisure) -
# 252: NEW YORK (CNN)  -- J
# 253: WASHINGTON (CNN)  --
# 254: (CNN) -- Thousands o
# 255: (CNN) -- A fast-movi
# 256: LONDON, England (CNN
# 257: Four alleged Venezue
# 258: WASHINGTON (CNN) --
# 259: Vero Beach, Florida
# 260: (CNN) -- A jury Thur
# 261: (CNN) -- Sri Lankan
# 262: CARACAS, Venezuela (
# 263: Joint Base Lewis-McC
# 264: Editor's note: Bryan
# 265: (CNN) -- Mike and Mi
# 266: LONDON, England -- E
# 267: Bali, Indonesia (CNN
# 268: (CNN) -- The U.S. Na
# 269: PARIS, France (CNN)
# 270: (CNN) -- Dr. Rajiv S
# 271: WASHINGTON (CNN) --
# 272: WASHINGTON (CNN) --
# 273: (CNN)  -- A man susp
# 274: (CNN) -- "Top Chef"
# 275: Atlanta (CNN) -- Rya
# 276: Washington (CNN) --
# 277: London, England (CNN
# 278: (CNN) -- "A calculat
# 279: Ercis, Turkey (CNN)
# 280: LAGOS, Nigeria (CNN)
# 281: ISLAMABAD, Pakistan
# 282: (CNN) -- Real Salt L
# 283: (CNN)  -- Skier Paul
# 284: (CNN)  -- With his h
# 285: (CNN) -- Three attac
# 286: LONDON, England (CNN
# 287: Bangkok (CNN) -- Muc
# 288: Rome, Italy (CNN)  -
# 289: (CNN) -- As hosts of
# 290: (PEOPLE.com) -- Rock
# 291: Nairobi, Kenya (CNN)
# 292: Miami, Florida (CNN)
# 293: PARIS, France (CNN)
# 294: (CNN) -- First it wa
# 295: (CNN) -- Early in Mi
# 296: (CNN) -- Susan Atkin
# 297: DOHA, Qatar (CNN) --
# 298: WASHINGTON (CNN) --
# 299: LONDON, England (CNN
# 300: (CNN) -- A Utah man
# 301: Fort Lauderdale, Flo
# 302: (CNN) -- Taliban adv
# 303: FORT CAMPBELL, Kentu
# 304: (CNN) -- Five people
# 305: (CNN) -- President O
# 306: MIDDLESBROUGH, Engla
# 307: Beijing, China (CNN)
# 308: WASHINGTON (CNN) --
# 309: SARATOGA SPRINGS, Ne
# 310: (CNN) -- A series of
# 311: (CNN) -- Andre Berto
# 312: (CNN) -- Struck by l
# 313: (CNN) -- She added s
# 314: TEHRAN, Iran (CNN)
# 315: (CNN)  -- England in
# 316: ATLANTA, Georgia (CN
# 317: Washington (CNN) --
# 318: (Tribune Media Servi
# 319: ISLAMABAD, Pakistan
# 320: (CNN)  -- Judging by
# 321: (CNN) -- River water
# 322: PADUCAH, Kentucky (C
# 323: (CNN) -- It's not as
# 324: (CNN) -- A United Na
# 325: (CNN) -- A woman con
# 326: (CNN) -- A mining co
# 327: Editor's Note: Donna
# 328: WASHINGTON (CNN) --
# 329: LONDON, England (CNN
# 330: (CNN) -- Sens. Hilla
# 331: (CNN)  -- From a sma
# 332: BUENOS AIRES, Argent
# 333: LOS ANGELES, Califor
# 334: London, England (CNN
# 335: (CNN) -- A racially-
# 336: BUENOS AIRES, Argent
# 337: (LonelyPlanet.com) -
# 338: LAS VEGAS, Nevada (C
# 339: (CNN) -- A children'
# 340: (CNN) -- Tax day is
# 341: (CNN)  -- Kuwait's l
# 342: (CNN) -- A 47-year-o
# 343: (CNN) -- One of the
# 344: JERUSALEM (CNN)  --
# 345: (CNN) -- The murdere
# 346: New York (CNN) -- Th
# 347: BURBANK, California
# 348: (CNN) -- U.S. Treasu
# 349: LAGOS, Nigeria (CNN)
# 350: (CNN) -- An armed ai
# 351: PARIS, France (CNN)
# 352: WASHINGTON (CNN) --
# 353: SEATTLE, Washington
# 354: (PEOPLE.com) -- Ther
# 355: (Mental Floss) -- Fr
# 356: (CNN) -- Officials w
# 357: (CNN) -- Americans a
# 358: (Wired)  -- Google i
# 359: PHOENIX, Arizona  --
# 360: ATLANTA, Georgia (CN
# 361: (CNN)  -- Former wor
# 362: ATHENS, Greece (CNN)
# 363: (CNN) -- Packing win
# 364: (Parenting.com) -- J
# 365: Peppermint oil, solu
# 366: (CNN) -- A former dr
# 367: SAN ANTONIO, Texas (
# 368: Baghdad, Iraq (CNN)
# 369: CLARENCE CENTER, New
# 370: New York (CNN) -- Pr
# 371: (PEOPLE.com) -- Two
# 372: BAGHDAD, Iraq (CNN)
# 373: (CNN) -- Evangelical
# 374: (CNN Student News) -
# 375: (CNN) -- U.S. Presid
# 376: ISLAMABAD, Pakistan
# 377: Los Angeles (CNN)  -
# 378: (CNN) -- Will Smith'
# 379: (CNN) -- A timeline
# 380: (CNN) -- Taping of "
# 381: (CNN) -- Back in 200
# 382: Washington (CNN) --
# 383: (Mental Floss) -- We
# 384: Washington (CNN) --
# 385: (CNN) -- If an e-mai
# 386: TEHRAN, Iran (CNN) -
# 387: Watch the full inter
# 388: (Budget Travel) -- L
# 389: (CNN) -- A Democrati
# 390: (CNN)      -- China
# 391: Editor's note: CNN a
# 392: (CNN) -- A former Al
# 393: (CNN)  -- A man who
# 394: A Nigerian politicia
# 395: (CNN) -- Explorer De
# 396: KABUL, Afghanistan (
# 397: (CNN) -- He's gone f
# 398: WASHINGTON (CNN)  --
# 399: (CNN) -- The nation'

# %%
import pickle

def convert_pkl_to_txt(pkl_file_path, txt_file_path):
    # Load the pickle file
    with open(pkl_file_path, 'rb') as pkl_file:
        data = pickle.load(pkl_file)
    
    # Save the data to a text file
    with open(txt_file_path, 'w', encoding='utf-8') as txt_file:
        txt_file.write(str(data))

# Example usage
pkl_file_path = './data/eval_dict_qa_crawl_vn.pkl'
txt_file_path = './data/eval_dict_qa_crawl_vn.txt'
convert_pkl_to_txt(pkl_file_path, txt_file_path)
